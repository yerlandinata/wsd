# %%
import pandas as pd
import numpy as np
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import matplotlib.pyplot as plt
import string

# %% [markdown]
# # Load Data

# %%
single_agree = pd.read_csv('../single_annotator.csv')
double_agree = pd.read_csv('../double_annotator_agree.csv')
triple_agree = pd.read_csv('../triple_annotator_agree.csv')

# %%
double_disagree = pd.read_csv('../double_annotator_disagree.csv')
triple_disagree = pd.read_csv('../triple_annotator_disagree.csv')

# %%
single_agree.head()
# Out:
#    kalimat_id   kata sense                                            kalimat
# 0      336691  cerah  4801          Cuaca cerah adalah lazim sepanjang tahun.
# 1      336270  cerah  4801  Gambar yang dihasilkan oleh layarnya cukup cer...
# 2      336555  cerah  4803  Masa depan yang cerah bagi pemuda berumur 20 d...
# 3      336618  cerah  4801  Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4      336613  cerah  4801  Sanders lebih menyukai cat air untuk Lilo deng...

# %% [markdown]
# # Summarize

# %%
len({*set(single_agree.kata), *set(double_agree.kata), *set(triple_agree.kata), *set(double_disagree.kata), *set(triple_disagree.kata)})
# Out:
# 54

# %% [markdown]
# There are 54 annotated ambiguous words in combined dataset

# %%
len({*set(single_agree.kalimat_id), *set(double_agree.kalimat_id), *set(triple_agree.kalimat_id),
     *set(double_disagree.kalimat_id), *set(triple_disagree.kalimat_id)})
# Out:
# 10297

# %% [markdown]
# There are 10298 annotated sentence in combined dataset

# %%
len({*set(single_agree.kalimat_id), *set(double_agree.kalimat_id), *set(triple_agree.kalimat_id)})
# Out:
# 8981

# %% [markdown]
# However, there are only 8992 annotated sentence in dataset without disagreement between annotators

# %% [markdown]
# # Merge no-conflict-between-annotators-dataset

# %%
dataset_kalimat_id = [*list(single_agree.kalimat_id), *list(double_agree.kalimat_id), *list(triple_agree.kalimat_id)]
dataset_kata = [*list(single_agree.kata), *list(double_agree.kata), *list(triple_agree.kata)]
dataset_sense = [*list(single_agree.sense), *list(double_agree.sense), *list(triple_agree.sense)]
dataset_kalimat = [*list(single_agree.kalimat), *list(double_agree.kalimat), *list(triple_agree.kalimat)]

# %%
dataset = pd.DataFrame({
    'kalimat_id': dataset_kalimat_id,
    'kata': dataset_kata,
    'sense': dataset_sense,
    'kalimat': dataset_kalimat
})

# %%
dataset.head()
# Out:
#    kalimat_id   kata sense                                            kalimat
# 0      336691  cerah  4801          Cuaca cerah adalah lazim sepanjang tahun.
# 1      336270  cerah  4801  Gambar yang dihasilkan oleh layarnya cukup cer...
# 2      336555  cerah  4803  Masa depan yang cerah bagi pemuda berumur 20 d...
# 3      336618  cerah  4801  Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4      336613  cerah  4801  Sanders lebih menyukai cat air untuk Lilo deng...

# %% [markdown]
# # Begin data cleaning
# Based on Edi Faisal, et. al (2018)

# %%
dataset['clean'] = pd.Series(['' for i in range(len(dataset))])

# %%
dataset.head()
# Out:
#    kalimat_id   kata sense                                            kalimat  \
# 0      336691  cerah  4801          Cuaca cerah adalah lazim sepanjang tahun.
# 1      336270  cerah  4801  Gambar yang dihasilkan oleh layarnya cukup cer...
# 2      336555  cerah  4803  Masa depan yang cerah bagi pemuda berumur 20 d...
# 3      336618  cerah  4801  Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4      336613  cerah  4801  Sanders lebih menyukai cat air untuk Lilo deng...
#
#   clean
# 0
# 1
# 2
# 3
# 4

# %%
annotated_words = set(dataset.kata)

# %%
# exceptions, do not stem
exception_words = {'senilai', 'bernilai'}

# %%
stemmer = StemmerFactory().create_stemmer()
clean_word = lambda w: w.translate(str.maketrans('', '', string.punctuation)).lower()

# %% [markdown]
# ## Money normalizer

# %%
def normalize_money(s):
    s = s.replace('Rp ', 'Rp')
    tokens = []
    for t in s.split():
        if t[:2] == 'Rp':
            tokens.append('somemoney')
        else:
            tokens.append(t)
    return ' '.join(tokens)

# %% [markdown]
# ## Number normalizer

# %%
TERBILANG = [
    'satu', 'dua', 'tiga', 'empat', 'lima', 'enam', 'tujuh', 'delapan', 'sembilan', 'nol',
    'sepuluh', 'sebelas', 'belas', 'puluh', 'seratus', 'ratus', 'seribu', 'ribu'
]

def normalize_number(s):
    tokens = []
    for t in s.split():
        try:
            int(clean_word(t))
            tokens.append('somenumber')
        except:
            if t in TERBILANG:
                tokens.append('somenumber')
            else:
                tokens.append(t)
    result = ' '.join(tokens)
    while 'somenumber somenumber' in result:
        result = result.replace('somenumber somenumber', 'somenumber')
    return result

# %% [markdown]
# ## Stemming, lowercasing, punctuation removal, repeated-words removal

# %%
def stem(s):
    tokens = []
    for t in s.split():
        if clean_word(t) not in {*annotated_words, *exception_words}:
            tokens.append(stemmer.stem(t))
        else:
            tokens.append(clean_word(t))
    return ' '.join(tokens)

# %% [markdown]
# ## Stop-words removal

# %%
with open('../stop_words.txt', 'r') as f:
    stop_words = f.readlines()
stop_words = list(map(str.strip, stop_words))
stop_words = list(filter(lambda w: w not in {*annotated_words, *exception_words}, stop_words))

remove_stop_words = lambda s: ' '.join(word for word in s.split() if word not in stop_words)

# %%
'paling' in stop_words
# Out:
# True

# %% [markdown]
# ## Execute cleaning

# %%
from functools import reduce
pipe = lambda *args: lambda x: reduce(lambda acc, f: f(acc), args, x)

# %%
dataset['clean'] = pd.Series(
    map(
        pipe(
            normalize_money,
            normalize_number,
            stem,
            remove_stop_words,
        ),
        dataset.kalimat
    )
)

# %%
dataset.head()
# Out:
#    kalimat_id   kata sense                                            kalimat  \
# 0      336691  cerah  4801          Cuaca cerah adalah lazim sepanjang tahun.
# 1      336270  cerah  4801  Gambar yang dihasilkan oleh layarnya cukup cer...
# 2      336555  cerah  4803  Masa depan yang cerah bagi pemuda berumur 20 d...
# 3      336618  cerah  4801  Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4      336613  cerah  4801  Sanders lebih menyukai cat air untuk Lilo deng...
#
#                                                clean  targetpos_clean  \
# 0                    cuaca cerah lazim panjang tahun                1
# 1  gambar hasil layar cukup cerah milik speaker h...                4
# 2  masa cerah pemuda umur somenumber prancis abad...                1
# 3  cor caroli alpha canum venaticorum nama lengka...               12
# 4  sanders suka cat air untuk lilo maksud tampil ...                9
#
#    targetpos_ori
# 0              1
# 1              6
# 2              3
# 3             16
# 4             11

# %% [markdown]
# # Write down the position of target word

# %%
targetpos = [-1 for i in range(len(dataset))]

# %%
for i in range(len(dataset)):
    target = dataset.iloc[i].kata
    tokens = dataset.iloc[i].clean.split()
    for j in range(len(tokens)):
        if tokens[j].find(target) >= 0 or stemmer.stem(tokens[j]) == stemmer.stem(target):
            targetpos[i] = j
            break
    if targetpos[i] == -1:
        print(target)
        print(tokens)
        print(dataset.iloc[i].kalimat)
        print(i)
        raise Exception

# %%
dataset['targetpos_clean'] = pd.Series(targetpos)

# %%
targetpos_ori = [-1 for i in range(len(dataset))]

# %%
for i in range(len(dataset)):
    target = dataset.iloc[i].kata
    tokens = dataset.iloc[i].kalimat.split()
    for j in range(len(tokens)):
        token = clean_word(tokens[j])
        if token.find(target) >= 0 or stemmer.stem(token) == stemmer.stem(target):
            targetpos_ori[i] = j
            break
    if targetpos_ori[i] == -1:
        print(target)
        print(tokens)
        print(dataset.iloc[i].kalimat)
        print(i)
        raise Exception

# %%
dataset['targetpos_ori'] = pd.Series(targetpos_ori)

# %%
dataset
# Out:
#       kalimat_id        kata sense  \
# 0         336691       cerah  4801
# 1         336270       cerah  4801
# 2         336555       cerah  4803
# 3         336618       cerah  4801
# 4         336613       cerah  4801
# 5         336406       cerah  4801
# 6         336324       cerah  4801
# 7         336401       cerah  4801
# 8         336426       cerah  4801
# 9         337760      coklat  4703
# 10        337381      coklat  470d
# 11        337629      coklat  4703
# 12        337446      coklat  4703
# 13        338100      coklat  4703
# 14        337480      coklat  4703
# 15        336955      coklat  4703
# 16        816088       jalan  1902
# 17        810534       jalan  1903
# 18        809166       jalan  1901
# 19        811504       jalan  1901
# 20        814156       jalan  1901
# 21        811170       jalan  1901
# 22        824010       jalan  190b
# 23        819672       jalan  1901
# 24        817018       jalan  190b
# 25       1053941      sarung  120d
# 26       1053936      sarung  1202
# 27       1053976      sarung  1202
# 28       1053713      sarung  1201
# 29       1053857      sarung  1201
# ...          ...         ...   ...
# 8954      990524    menerima  3101
# 8955      992709    menerima  3101
# 8956      993076    menerima  3101
# 8957      993657  mengandung  2301
# 8958      994040  mengandung  2301
# 8959      994086  mengandung  2301
# 8960      994244  mengandung  2301
# 8961      994350  mengandung  2301
# 8962      995462  mengandung  2301
# 8963      995744  mengandung  2301
# 8964      995799  mengandung  2301
# 8965      996044  mengandung  2301
# 8966      996346  mengandung  2301
# 8967      996484  mengandung  2301
# 8968      996509  mengandung  2301
# 8969      996885  mengandung  2301
# 8970      996944  mengandung  2301
# 8971      996966  mengandung  2301
# 8972      996975  mengandung  2301
# 8973      997027  mengandung  2301
# 8974      997491  mengandung  2301
# 8975      997936  mengandung  2301
# 8976      998087  mengandung  2301
# 8977      998233  mengandung  2301
# 8978      998640  mengandung  2301
# 8979      998683  mengandung  2301
# 8980      998844  mengandung  2301
# 8981      999059  mengandung  2301
# 8982      999349  mengandung  2301
# 8983      999660  mengandung  2301
#
#                                                 kalimat  \
# 0             Cuaca cerah adalah lazim sepanjang tahun.
# 1     Gambar yang dihasilkan oleh layarnya cukup cer...
# 2     Masa depan yang cerah bagi pemuda berumur 20 d...
# 3     Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4     Sanders lebih menyukai cat air untuk Lilo deng...
# 5     Ulleungdo memiliki iklim subtropis basah (Klas...
# 6     Ikan hias kemungkinan besar sulit bertahan hid...
# 7     Sebuah entremet menandai berakhirnya sajian su...
# 8     Alangkah lega hatinya ketika ia mulai melihat ...
# 9     Sisi atas tubuh berwarna coklat tembaga keemasan.
# 10    Dari hasil pengujian menunjukkan bahwa ada beb...
# 11    Lucy memiliki mata coklat dan rambut pirang se...
# 12    Punggung dan badannya berwarna coklat kelabu d...
# 13    Jenis koral yang seringkali ditemukan adalah k...
# 14    Kepala berwarna coklat kemerahan dengan garis ...
# 15    Pada remaja memiliki corak coklat berbintik ku...
# 16    Rancangan Pei menempatkan kotak sepatu kaku di...
# 17    Selain jalan cerita,kostum yang digunakan juga...
# 18    Taraf hidup masyarakat meningkat dengan diduku...
# 19    Terdapat lima jalan tol besar yang menghubungk...
# 20    Sejumlah jalan dan tempat di kota ini diberi n...
# 21    Tol Serang - Panimbang merupakan jalan tol yan...
# 22    Perbatasan dengan Paroki Santo Petrus Lubukbaj...
# 23    Tanah Siang merupakan jalan yang dibuat pada z...
# 24    Pulo Geulis dapat dicapai dengan berjalan kaki...
# 25    Pemain bertelanjang dada, namun mengenakan pak...
# 26    Sehelai sarung menutupi pinggang hingga kaki d...
# 27    Lungi, juga dikenal sebagai sarung, adalah pak...
# 28    Kayu mahang damar tidak banyak dimanfaatkan; p...
# 29    Anton Gabrielle alias The Wonderboy (Robertino...
# ...                                                 ...
# 8954  Pada Juli 2008 PLUNA menerima pesawat kelimany...
# 8955  Atrium berfungsi sebagai ruang resepsi tempat ...
# 8956  Pada tahun 1970, ia menerima beasiswa militer ...
# 8957  Tidak ada inti stabil di alam yang mengandung ...
# 8958  Target utama misi ini adalah Europa, yang didu...
# 8959  Pada 18 Januari 2007, Sanger mengumumkan bahwa...
# 8960  Band ini dikenal dengan genre Metalcore pada d...
# 8961  Terdapat lebih dari 3000 buku yang judulnya me...
# 8962  Satelit jenis ini juga dapat memonitor perubah...
# 8963  Enclosed Alphanumeric Supplement adalah blok U...
# 8964  Khmer adalah blok Unicode yang mengandung kara...
# 8965  Softlens (lensa kontak) adalah sebuah alat yan...
# 8966  Daun kubis juga mengandung kelompok glukosinol...
# 8967  Banyak seni beladiri mengandung latihan pergum...
# 8968  Pusat germinal pertama kali didefinisikan oleh...
# 8969   Buah ini mengandung banyak vitamin C, dan tanin.
# 8970  Akibatnya, KOH biasanya mengandung berbagai ju...
# 8971  Senyawa yang mengandung lebih dari satu jenis ...
# 8972  Di samping mengandung bisa, air liur komodo ju...
# 8973  Sekitar 20% pasien yang ditangani dengan dapso...
# 8974  Tapi lokasi Taj mengandung beberapa kuburan se...
# 8975  Terdapat beberapa kombinasi vaksin antara vaks...
# 8976  Pada kasus tertentu implan mengandung perangka...
# 8977  Di samping kedua singel tersebut, isi lagu dal...
# 8978  Maka seluruh alam semesta mengandung diri Alla...
# 8979  Molekul-molekul yang mengandung 4n elektron pi...
# 8980  Diperkirakan, Salar de Uyuni mengandung 10 mil...
# 8981  Injil yang ada saat ini mengandung firman Alla...
# 8982  Selain itu, sebagian episode mengandung setida...
# 8983  Para peneliti telah mengembangkan galur semang...
#
#                                                   clean  targetpos_clean  \
# 0                       cuaca cerah lazim panjang tahun                1
# 1     gambar hasil layar cukup cerah milik speaker h...                4
# 2     masa cerah pemuda umur somenumber prancis abad...                1
# 3     cor caroli alpha canum venaticorum nama lengka...               12
# 4     sanders suka cat air untuk lilo maksud tampil ...                9
# 5     ulleungdo milik iklim subtropis basah klasifik...               14
# 6     ikan hias besar sulit tahan hidup alam liar ak...               10
# 7     buah entremet tanda akhir saji set menu upa mu...               14
# 8     alangkah lega hati mulai lihat binatang ternak...               14
# 9             sisi atas tubuh warna coklat tembaga emas                4
# 10    hasil uji tunjuk varietas tahan hadap wereng c...                7
# 11    lucy milik mata coklat rambut pirang panjang b...                3
# 12    punggung badan warna coklat kelabu somenumber ...                3
# 13    jenis koral seringkali temu karang daging pori...               10
# 14    kepala warna coklat merah garis hitam mata ten...                2
# 15       remaja milik corak coklat bintik kuning coklat                3
# 16    rancang pei tempat kotak sepatu kaku buah sudu...                9
# 17                jalan cerita kostum guna sesuai zaman                0
# 18    taraf hidup masyarakat tingkat dukung jalan de...                5
# 19    somenumber jalan tol besar hubung distrik bisn...                1
# 20    jumlah jalan tempat kota beri nama ilmuwan mat...                1
# 21    tol serang - panimbang rupa jalan tol hubung s...                5
# 22    batas paroki santo petrus lubukbaja jalan yos ...                5
# 23    tanah siang rupa jalan zaman jajah hindia belanda                3
# 24    pulo geulis capai jalan kaki lewat jembatan hu...                3
# 25    main telanjang dada kena pakai perang lindung ...               14
# 26    hela sarung tutup pinggang kaki baju tipis lon...                1
# 27                lung kenal sarung pakai kena pinggang                2
# 28    kayu mahang damar manfaat sarung alat potong k...                4
# 29    anton gabrielle alias the wonderboy robertino ...               11
# ...                                                 ...              ...
# 8954  juli somenumber pluna menerima pesawat lima to...                3
# 8955  atrium fungsi ruang resepsi tempat paterfamili...               18
# 8956  tahun somenumber menerima beasiswa militer unt...                2
# 8957  inti stabil alam mengandung somenumber nukleon...                3
# 8958  target utama misi europa duga milik samudra ba...                9
# 8959  somenumber januari somenumber sanger umum proy...                7
# 8960  band kenal genre metalcore debut sounding the ...                9
# 8961  somenumber buku judul mengandung kata pemimipi...                3
# 8962  satelit jenis monitor ubah iklim teliti ekolog...               10
# 8963  enclosed alphanumeric supplement blok unicode ...                5
# 8964  khmer blok unicode mengandung karakter untuk t...                3
# 8965  softlens lensa kontak buah alat guna untuk ban...               16
# 8966  daun kubis mengandung kelompok glukosinolat ra...                2
# 8967  seni beladiri mengandung latih gumul tekan var...                2
# 8968  pusat germinal pertama kali definisi walther f...               14
# 8969                    buah mengandung vitamin c tanin                1
# 8970  akibat koh mengandung jumlah air karbonat liha...                2
# 8971        senyawa mengandung somenumber jenis halogen                1
# 8972  samping mengandung bisa air liur komodo milik ...                1
# 8973  somenumber pasien tangan dapson derita hemolis...               17
# 8974  lokasi taj mengandung kubur paviliun timur sel...                2
# 8975  kombinasi vaksin vaksin tetanus vaksin dtap td...                7
# 8976  kasus implan mengandung perangkat elektronik j...                2
# 8977  samping dua singel sebut isi lagu dalam album ...               10
# 8978  alam semesta mengandung allah allah satu wujud...                2
# 8979     molekul mengandung 4n elektron pi antiaromatik                1
# 8980  kira salar de uyuni mengandung somenumber mili...                4
# 8981  injil mengandung firman allah riwayat isa tuli...                1
# 8982  episode mengandung somenumber tunjuk dalam bah...                1
# 8983  teliti kembang galur semanggi mengandung kumar...                4
#
#       targetpos_ori
# 0                 1
# 1                 6
# 2                 3
# 3                16
# 4                11
# 5                18
# 6                13
# 7                22
# 8                19
# 9                 4
# 10               12
# 11                3
# 12                4
# 13               14
# 14                2
# 15                4
# 16               11
# 17                1
# 18                7
# 19                2
# 20                1
# 21                5
# 22                7
# 23                3
# 24                5
# 25               17
# 26                1
# 27                4
# 28                8
# 29               11
# ...             ...
# 8954              4
# 8955             24
# 8956              4
# 8957              7
# 8958             15
# 8959             13
# 8960             14
# 8961              7
# 8962             15
# 8963              7
# 8964              5
# 8965             25
# 8966              3
# 8967              3
# 8968             21
# 8969              2
# 8970              3
# 8971              2
# 8972              2
# 8973             28
# 8974              3
# 8975             15
# 8976              4
# 8977             14
# 8978              4
# 8979              2
# 8980              4
# 8981              5
# 8982              4
# 8983              8
#
# [8984 rows x 7 columns]

# %%
dataset.iloc[100].clean
# Out:
# 'misal orang tenaga ajar honorer punya beban ajar somenumber jam dalam minggu honor besar somemoney jam dalam masa somenumber minggu bulan honor somemoney'

# %%
dataset.to_csv('train_data.csv')

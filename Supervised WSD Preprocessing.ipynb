# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %%
single_agree = pd.read_csv('../single_annotator.csv')
double_agree = pd.read_csv('../double_annotator_agree.csv')
triple_agree = pd.read_csv('../triple_annotator_agree.csv')

# %%
double_disagree = pd.read_csv('../double_annotator_disagree.csv')
triple_disagree = pd.read_csv('../triple_annotator_disagree.csv')

# %%
single_agree.head()
# Out:
#    kalimat_id   kata sense                                            kalimat
# 0      336691  cerah  4801          Cuaca cerah adalah lazim sepanjang tahun.
# 1      336270  cerah  4801  Gambar yang dihasilkan oleh layarnya cukup cer...
# 2      336555  cerah  4803  Masa depan yang cerah bagi pemuda berumur 20 d...
# 3      336618  cerah  4801  Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4      336613  cerah  4801  Sanders lebih menyukai cat air untuk Lilo deng...

# %% [markdown]
# # Summarize

# %%
len({*set(single_agree.kata), *set(double_agree.kata), *set(triple_agree.kata), *set(double_disagree.kata), *set(triple_disagree.kata)})
# Out:
# 54

# %%
len({*set(single_agree.kalimat_id), *set(double_agree.kalimat_id), *set(triple_agree.kalimat_id),
     *set(double_disagree.kalimat_id), *set(triple_disagree.kalimat_id)})
# Out:
# 10314

# %%
len({*set(single_agree.kalimat_id), *set(double_agree.kalimat_id), *set(triple_agree.kalimat_id)})
# Out:
# 8998

# %% [markdown]
# However, there are only 8992 annotated sentence in dataset without disagreement between annotators

# %% [markdown]
# # Merge no-conflict-between-annotators-dataset

# %%
dataset_kalimat_id = [*list(single_agree.kalimat_id), *list(double_agree.kalimat_id), *list(triple_agree.kalimat_id)]
dataset_kata = [*list(single_agree.kata), *list(double_agree.kata), *list(triple_agree.kata)]
dataset_sense = [*list(single_agree.sense), *list(double_agree.sense), *list(triple_agree.sense)]
dataset_kalimat = [*list(single_agree.kalimat), *list(double_agree.kalimat), *list(triple_agree.kalimat)]

# %% [markdown]
# # Test Dataset

# %%
dataset = pd.read_csv('../testing_data.csv').rename(columns={'word': 'kata'})

# %%
dataset.head()
# Out:
#     id   kata                                            kalimat
# 0   13  asing  Para pecinta film indonesia atau tv, pasti tak...
# 1   19  asing  Pasti telinga kita merasa asing dan aneh mende...
# 2   41  asing  Warga negara asing atau warga negara Persemakm...
# 3   44  asing  Selama lima belas tahun memerintah, Sultan Mah...
# 4  121  asing  Yang kemudian diikuti dengan donat-donat waral...

# %% [markdown]
# # Only WSD Tasks

# %%
wsd_dataset_kalimat = []
wsd_dataset_kata = []
wsd_dataset_sense = []

for sense, kata, kalimat in zip(dataset_sense, dataset_kata, dataset_kalimat):
    if str(sense)[-1] not in 'abcdx':
        wsd_dataset_kata.append(kata)
        wsd_dataset_sense.append(sense)
        wsd_dataset_kalimat.append(kalimat)
        
dataset = pd.DataFrame({
    'kata': wsd_dataset_kata,
    'sense': wsd_dataset_sense,
    'kalimat': wsd_dataset_kalimat
})

dataset.head()
# Out:
#     kata sense                                            kalimat
# 0  cerah  4801          Cuaca cerah adalah lazim sepanjang tahun.
# 1  cerah  4801  Gambar yang dihasilkan oleh layarnya cukup cer...
# 2  cerah  4803  Masa depan yang cerah bagi pemuda berumur 20 d...
# 3  cerah  4801  Cor Caroli (Alpha Canum Venaticorum), (nama le...
# 4  cerah  4801  Sanders lebih menyukai cat air untuk Lilo deng...

# %%
len(dataset)
# Out:
# 8407

# %% [markdown]
# # POS Tagging

# %%
import nltk
from preprocessor import pipe

# %%
annotated_words = set(dataset.kata)

ct = nltk.tag.CRFTagger()
ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')

# %%
dataset['pos_tags'] = list(map(
    pipe(
        nltk.word_tokenize,
        lambda tokens: [tokens],
        ct.tag_sents,
        lambda pos_tags_sentence: pos_tags_sentence[0]
    ),
    dataset.kalimat
))

# %%
dataset.iloc[0].pos_tags
# Out:
# [('Para', 'DT'),
#  ('pecinta', 'NN'),
#  ('film', 'NN'),
#  ('indonesia', 'NN'),
#  ('atau', 'CC'),
#  ('tv', 'NNP'),
#  (',', 'Z'),
#  ('pasti', 'RB'),
#  ('tak', 'NEG'),
#  ('asing', 'JJ'),
#  ('mendengar', 'VB'),
#  ('namanya', 'RB'),
#  ('.', 'Z')]

# %% [markdown]
# # Begin data cleaning

# %%
dataset['clean'] = pd.Series(['' for i in range(len(dataset))])

# %%
dataset.head()
# Out:
#     id   kata                                            kalimat  \
# 0   13  asing  Para pecinta film indonesia atau tv, pasti tak...
# 1   19  asing  Pasti telinga kita merasa asing dan aneh mende...
# 2   41  asing  Warga negara asing atau warga negara Persemakm...
# 3   44  asing  Selama lima belas tahun memerintah, Sultan Mah...
# 4  121  asing  Yang kemudian diikuti dengan donat-donat waral...
#
#                                             pos_tags clean
# 0  [(Para, DT), (pecinta, NN), (film, NN), (indon...
# 1  [(Pasti, NN), (telinga, NN), (kita, PRP), (mer...
# 2  [(Warga, NN), (negara, NN), (asing, JJ), (atau...
# 3  [(Selama, IN), (lima, CD), (belas, NN), (tahun...
# 4  [(Yang, DT), (kemudian, CC), (diikuti, VB), (d...

# %% [markdown]
# ## Execute cleaning

# %%
import time
from preprocessor import (
    normalize_money, normalize_number, remove_punctuation,
    create_stemmer, create_stop_words_remover, stemmer,
    clean_word, normalize_weekday, normalize_month, remove_normalized,
    normalize_personal_pronoun, normalize_demonstrative_pronoun, normalize_coordinating_conjunction,
    normalize_determiner, normalize_preposition, create_obvious_verb_normalizer
)

# %%
# exceptions, do not stem, because pysastrawi is stupid
exception_words = {'senilai', 'bernilai', 'menilainya', 'dinilainya', *set(map(stemmer.stem, annotated_words))}

# %%
begin = time.perf_counter()
dataset['kalimat'] = pd.Series(
    map(
        pipe(
            remove_punctuation,
            normalize_money,
            normalize_number,
            normalize_weekday,
            normalize_month,
            create_stemmer(annotated_words, exception_words),
        ),
        dataset.kalimat
    )
)
print('elapsed time:', time.perf_counter() - begin)
# Out:
# elapsed time: 31.10038994899878

# %%
dataset.iloc[4244].kalimat
# Out:
# 'bagaimana jaringan nordsud hilang diri dari saing dengan dekorasi stasiun yang kualitas tinggi'

# %%
begin = time.perf_counter()
dataset['clean'] = pd.Series(
    map(
        pipe(
            create_obvious_verb_normalizer(annotated_words, exception_words),
            normalize_personal_pronoun,
            normalize_demonstrative_pronoun,
            normalize_coordinating_conjunction,
            normalize_determiner,
            normalize_preposition,
            remove_normalized,
            create_stop_words_remover(annotated_words, exception_words),
        ),
        dataset.kalimat
    )
)
print('elapsed time:', time.perf_counter() - begin)
# Out:
# elapsed time: 3.3653268730013224

# %%
dataset.head()
# Out:
#     id   kata                                            kalimat  \
# 0   13  asing  para cinta film indonesia atau tv pasti tak as...
# 1   19  asing  pasti telinga kita rasa asing dan aneh dengar ...
# 2   41  asing  warga negara asing atau warga negara makmur ya...
# 3   44  asing  lama somenumber tahun perintah sultan mahmud j...
# 4  121  asing  yang kemudian ikut dengan donatdonat waralaba ...
#
#                                             pos_tags  \
# 0  [(Para, DT), (pecinta, NN), (film, NN), (indon...
# 1  [(Pasti, NN), (telinga, NN), (kita, PRP), (mer...
# 2  [(Warga, NN), (negara, NN), (asing, JJ), (atau...
# 3  [(Selama, IN), (lima, CD), (belas, NN), (tahun...
# 4  [(Yang, DT), (kemudian, CC), (diikuti, VB), (d...
#
#                                                clean
# 0          cinta film indonesia tv asing dengar nama
# 1  telinga asing aneh dengar menu masakan soto ke...
# 2  warga negara asing warga negara makmur kepala ...
# 3  perintah sultan mahmud jalin kerja asing belan...
# 4  donatdonat waralaba asing master ring master d...

# %% [markdown]
# # Write down the position of target word

# %%
targetpos = [-1 for i in range(len(dataset))]

for i in range(len(dataset)):
    target = dataset.iloc[i].kata
    tokens = dataset.iloc[i].clean.split()
    for j in range(len(tokens)):
        if tokens[j].find(target) >= 0 or stemmer.stem(tokens[j]) == stemmer.stem(target):
            targetpos[i] = j
            break
    if targetpos[i] == -1:
        print(target)
        print(tokens)
        print(dataset.iloc[i].kalimat)
        print(i)
        raise Exception

dataset['targetpos_clean'] = pd.Series(targetpos)

# %%
targetpos_ori = [-1 for i in range(len(dataset))]

for i in range(len(dataset)):
    target = dataset.iloc[i].kata
    tokens = dataset.iloc[i].kalimat.split()
    for j in range(len(tokens)):
        token = clean_word(tokens[j])
        if token.find(target) >= 0 or stemmer.stem(token) == stemmer.stem(target):
            targetpos_ori[i] = j
            break
    if targetpos_ori[i] == -1:
        print(target)
        print(tokens)
        print(dataset.iloc[i].kalimat)
        print(i)
        raise Exception

dataset['targetpos_ori'] = pd.Series(targetpos_ori)

# %% [markdown]
# # Write down the ambiguous word POS tag and its immediate verb and noun

# %%
targetpos_pos_tag = [-1 for i in range(len(dataset))]
tags_only = ['' for i in range(len(dataset))]
immediate_verbs = []
immediate_nouns = []

def get_immediate_word_tag(tokens, targetpos, tag):
    res = []
    for i in range(targetpos+1, len(tokens)):
        if tokens[i][1] == tag:
            res.append(stemmer.stem(tokens[i][0]))
    for i in range(targetpos-1, -1, -1):
        if tokens[i][1] == tag:
            res.append(stemmer.stem(tokens[i][0]))
    return ' '.join(res)

for i in range(len(dataset)):
    target = dataset.iloc[i].kata
    tokens = dataset.iloc[i].pos_tags
    for j in range(len(tokens)):
        token = clean_word(tokens[j][0])
        if token.find(target) >= 0 or stemmer.stem(token) == stemmer.stem(target):
            targetpos_pos_tag[i] = j
            immediate_verbs.append(get_immediate_word_tag(tokens, j, 'VB'))
            immediate_nouns.append(get_immediate_word_tag(tokens, j, 'NN'))
            break
    if targetpos_pos_tag[i] == -1:
        print(target)
        print(tokens)
        print(dataset.iloc[i].kalimat)
        print(i)
        raise Exception
    tags_only[i] = ' '.join(list(map(lambda t: t[1], tokens)))

dataset['targetpos_pos_tag'] = pd.Series(targetpos_pos_tag)
dataset['pos_tags'] = pd.Series(tags_only)
dataset['verbs'] = pd.Series(immediate_verbs)
dataset['nouns'] = pd.Series(immediate_nouns)

# %%
dataset.iloc[1].pos_tags
# Out:
# 'NN NN PRP VB JJ CC JJ VB NN VB NN NN Z SC SC JJ VB VB NNP NNP CC NNP NNP Z'

# %%
dataset.query('kata == "dalam"')
# Out:
#           id   kata                                            kalimat  \
# 2853  339858  dalam  haji piobang adalah orang ulama dan tokoh pent...
# 2854  342460  dalam  minta inggris atas bantu militer dalam hadap k...
# 2855  345318  dalam  partaipartai politik besar di sarawak terbagi ...
# 2856  345861  dalam  naruto rasa salah karena luka sakura dalam wuj...
# 2857  346598  dalam  latih tiger atau operasi harimau adalah nama k...
# 2858  347739  dalam  mereka umum dukung semua klub dalam fk partiza...
# 2859  349312  dalam  agak mirip dengan herbarium yang murni ering b...
# 2860  350071  dalam  ayub somenumber disingkat ayb somenumber adala...
# 2861  350396  dalam  bijak sebut lalu timbul friksi dalam tubuh ira...
# 2862  350529  dalam  sementara sebab wasir yang sungguh belum tahu ...
# 2863  351571  dalam  alexius meni pada suatu saat dalam hidup tetap...
# 2864  352370  dalam  kandidat dalam pilih umum ini adalah nicos ana...
# 2865  352678  dalam  konon dalam pelayaran cheng ho yang ke somenum...
# 2866  353775  dalam  tawas rupa komponen dari foamite yang guna dal...
# 2867  354034  dalam  teks terjemah sebut cetak dalam huruf latin di...
# 2868  354240  dalam  saat ini mayoritas duduk adalah syiah meski da...
# 2869  354782  dalam  applikasi ini mudah para unjung dan guna dalam...
# 2870  360633  dalam  manusia mengasupnya dalam jumlah yang sangat v...
# 2871  363703  dalam  busyra yang rupa ahli sakit dalam ini adalah p...
# 2872  364049  dalam  superblok solo paragon diri dari somenumber la...
# 2873  364424  dalam  celana dalam wanita awal rancang untuk tutup p...
# 2874  366607  dalam  aka cachacrouensis adalah spesies spons yang g...
# 2875  367684  dalam  energi dalam ini pada akhir ionisasi atomatom ...
# 2876  369544  dalam  clathrina luteoculcitella adalah spesies spons...
# 2877  377374  dalam  ircinia fusca adalah spesies spons yang golong...
# 2878  379120  dalam  karya sebut rupa buku pertama dari jenis yang ...
# 2879  380456  dalam  felix dzerzhinsky kena serang jantung telah pi...
# 2880  381643  dalam  perang silesia mulai lebih dari abad rivalitas...
# 2881  386393  dalam  versi somenumber guna dalam alkitab edisi nova...
# 2882  387018  dalam  punya marginalia dan rupa pakai dalam liturgi ...
# ...      ...    ...                                                ...
# 3130  677650  dalam  edisi terbatas tampil somenumber ilustrasi dar...
# 3131  677913  dalam  orang aktivis hak sipil yang muka kee ungkap p...
# 3132  679288  dalam  ad universal ecclesiae adalah sebuah konstitus...
# 3133  682811  dalam  dapat somenumber pulau yang masuk ke dalam wil...
# 3134  682828  dalam  akan tetapi ketika armada sia telah labuh di w...
# 3135  683808  dalam  bagai orang pangeran muda ia keliling oleh ban...
# 3136  684545  dalam  bagai anggota akhir keluarga disney yang aktif...
# 3137  685819  dalam  kepung kota sebut hasil namun tingkah laku jen...
# 3138  687850  dalam  karena whitlam milik suara mayoritas dalam dew...
# 3139  688408  dalam  intervensi dalam mogok pullman pada somenumber...
# 3140  688752  dalam  untuk tingkat karier monroe ia bayar operasi s...
# 3141  689825  dalam  untuk ubah sebuah kata benda jadi bentuk jamak...
# 3142  691883  dalam  pada tahun somenumber panair do brasil berpart...
# 3143  693095  dalam  minta ini tidak kabul dengan alas pensiun gube...
# 3144  694870  dalam  robert noyce percaya bahwa microelektronik aka...
# 3145  695594  dalam  sembilan somenumber persen orang afrikaamerika...
# 3146  697349  dalam  laksana latih militer bagi warga sejak mereka ...
# 3147  700654  dalam  ia temu dengan michael schiavo pada somenumber...
# 3148  700745  dalam  cara lain adalah dengan referensi warnawarna s...
# 3149  700970  dalam  alfabet koptik punya sejarah panjang sejak zam...
# 3150  701104  dalam  individu yang punya informasi non publik dan m...
# 3151  703447  dalam  kanuragan adalah ilmu yang fungsi untuk bela d...
# 3152  704150  dalam  sinergi ini hal yang unik dan baru pertama kal...
# 3153  704453  dalam  belum muncul televisi hologram teknologi bas h...
# 3154  706355  dalam  video klip dari grup ini sering tampil dalam a...
# 3155  707738  dalam  banyak warung kopi di timur tengah dan di wila...
# 3156  708228  dalam  bagai pegang pimpin utama dalam suatu biliku k...
# 3157  709927  dalam  sama dengan sd pada umum di indonesia masa did...
# 3158  710652  dalam  dengan demikian dalam aristophanes di plutus a...
# 3159  713084  dalam  opera dengan padu suara yang megah diri verdi ...
#
#                                                pos_tags  \
# 2853      NNP NNP VB NND NN CC NN JJ IN NN NNP IN NNP Z
# 2854  NN NNP IN NN NN IN VB NNP NNP IN NN SC VB IN N...
# 2855  NN NN JJ IN NNP VB IN CD NN Z NN JJ NN Z NN JJ...
# 2856              NN VB VB SC VB NNP IN NNP NNP VB CD Z
# 2857  NNP NNP Z CC NNP NNP Z VB NN NN SC CD IN NN NN...
# 2858  PRP RB VB CD NN IN NNP NNP Z CC VB NN JJ CC JJ...
# 2859  RB JJ IN NN SC VB NN NN CC NN JJ CC NN NN Z IN...
# 2860  NNP CD Z NN NNP CD Z VB NN IN NNP NNP IN NNP N...
# 2861  NN PR CC VB NN IN NN NNP SC VB NN JJ NNP IN NN...
# 2862  SC NN NN SC RB NEG VB Z CD NN SC VB NN NN Z NN...
# 2863  NNP VB IN CD NN IN NN Z CC DT NN NN JJ VB NN I...
# 2864  NN IN NN JJ PR VB NNP NNP SC VB IN NNP NNP Z N...
# 2865  NNP Z IN NN NNP NNP SC IN CD Z CD Z Z PRP VB I...
# 2866                NNP VB NN IN NN SC VB IN NN VB NN Z
# 2867             NN NN PR VB IN NN NN IN NNP IN NN CD Z
# 2868  NN PR NN RB VB NNP SC VB RB NN NNP CC NNP IN N...
# 2869                    NN PR VB DT NN CC RB IN NN CD Z
# 2870              NNP RB IN NN SC RB VB Z VB NN CC NN Z
# 2871  NNP SC VB NN NN IN PR VB NN NNP NNP Z NNP Z NN...
# 2872  NNP NNP NNP VB IN CD NN NNP NNP NNP Z NNP NNP ...
# 2873                  NNP IN NN RB VB SC VB CD NND NN Z
# 2874                   NN NN VB FW FW SC VB IN NN NNP Z
# 2875              NN IN PR IN NN NN NN CC NN NN SC VB Z
# 2876                 NNP NNP VB FW FW SC VB IN NN NNP Z
# 2877                 NNP NNP VB FW FW SC VB IN NN NNP Z
# 2878           NN PR VB NN OD IN NN SC VB IN NN SC NN Z
# 2879  NNP NNP VB NN NN SC NN IN CD NN JJ Z IN NN NNP...
# 2880  NNP NNP VB RB IN NN NN CC NN IN NNP CC NNP IN ...
# 2881                      NN CD VB IN NNP NNP NNP NNP Z
# 2882                        NNP NNP CC RB VB IN NN NN Z
# ...                                                 ...
# 3130  NN NN VB CD NN IN NNP NNP SC NEG MD VB IN NN N...
# 3131  NND NN NN JJ SC JJ Z NNP VB RB VB NN IN CD CD ...
# 3132  NNP NNP NNP VB NND NNP NNP SC VB IN NN IN NN N...
# 3133  VB CD NN SC VB IN NN NN NN NNP NNP NNP NNP IN ...
# 3134  NN CC Z SC NN NNP MD VB IN NN NNP Z NN SC VB I...
# 3135  IN NND NN JJ Z PRP VB IN CD NN CC NN SC IN NN ...
# 3136  IN NN JJ NN NNP SC JJ VB IN NN PR Z NNP NNP RB...
# 3137  NN NN PR VB Z CC NN NN JJ NNP Z NNP Z VB CD NN...
# 3138  SC NNP VB NN NN IN NNP NNP NNP NNP Z NN NN NNP...
# 3139  RB IN NNP NNP IN CD SC VB NN NN RB VB Z VB NN ...
# 3140  SC VB FW FW Z PRP VB NN NN SC NN NN CC MD VB Z...
# 3141  SC VB NND VB NN VB NN NN Z NN NN Z NN VB Z Z C...
# 3142  IN NN CD NNP NNP NNP VB IN NNP NNP NNP Z IN NN...
# 3143  NN PR NEG VB IN NN NN NNP NNP MD RB VB NN IN N...
# 3144  NNP NNP VB SC JJ MD RB VB IN NN CC RB JJ IN NN...
# 3145  CD CD CD NN NNP IN NNP VB CC IN VB SC VB NN NN...
# 3146  VB NN NN IN NN IN PRP MD VB Z NN NNP VB JJ CD ...
# 3147  PRP VB IN NNP NNP IN CD IN NND NN NN IN NNP NN...
# 3148  NN JJ VB SC VB NN PR IN NN IN NNP NNP Z MD CC ...
# 3149  NNP NNP VB NN JJ Z IN NN NNP NNP IN NNP CC NNP...
# 3150  NN SC VB NN RB NN CC RB IN NN NN CC NN Z VB NN...
# 3151  NN VB NN SC VB SC VB NN IN NN CC IN NN IN NN J...
# 3152  NN PR NN SC JJ CC JJ OD NND VB IN NNP Z NN NN ...
# 3153  SC VB NN NN Z NN VB NN MD VB IN NN NN Z IN IN ...
# 3154        NNP VB IN NN PR RB VB IN NN NN IN NNP NNP Z
# 3155  CD NN NN IN NNP NNP CC IN NN NN NNP NNP CC NN ...
# 3156  IN NN NN JJ IN CD NN Z NN JJ Z Z NND NN Z VB Z...
# 3157  NNP IN NNP IN NN IN NNP NN NN NN IN NN CD NNP ...
# 3158  IN PR Z IN NNP IN NNP Z NN CD Z NND NN JJ VB I...
# 3159  NNP IN NN NN SC MD VB NNP IN NN JJ IN NN CD NNP Z
#
#                                                   clean  targetpos_clean  \
# 2853  haji piobang orang ulama tokoh dalam gera padr...                5
# 2854  inggris atas bantu militer dalam hadap krisis ...                4
# 2855  partaipartai politik besar sarawak terbagi dal...                5
# 2856   naruto salah luka sakura dalam wujud kyuubi ekor                4
# 2857  latih tiger operasi harimau nama kode dalam ra...                6
# 2858  dukung klub dalam fk partizan pakai simbol hit...                2
# 2859  herbarium murni ering bunga tumbuh kering warn...                8
# 2860  ayub ayb kitab ayub alkitab ibrani janji dalam...                7
# 2861  bijak timbul friksi dalam tubuh ira perang sip...                3
# 2862  wasir sungguh faktor tingkat tekan intraabdome...               10
# 2863  alexius meni dalam hidup tulis kontemporer gag...                2
# 2864  kandidat dalam pilih nicos anastasiades usung ...                1
# 2865  konon dalam pelayaran cheng ho singgah blamban...                1
# 2866  tawas rupa komponen foamite dalam alat madam b...                4
# 2867        teks terjemah cetak dalam huruf latin medan                3
# 2868    mayoritas duduk syiah duduk sunni kristen dalam                6
# 2869            applikasi mudah unjung dalam akses 9gag                3
# 2870  manusia mengasupnya dalam variasi gantung loka...                2
# 2871  busyra rupa ahli sakit dalam putra koto gadang...                4
# 2872  superblok solo paragon lantai hotel and reside...               18
# 2873  celana dalam wanita rancang tutup paruh kaki p...                1
# 2874  aka cachacrouensis spesies spons golong dalam ...                5
# 2875  energi dalam ionisasi atomatom disosiasi molek...                1
# 2876  clathrina luteoculcitella spesies spons golong...                5
# 2877  ircinia fusca spesies spons golong dalam kelas...                5
# 2878      karya rupa buku jenis muat dalam ukur seragam                5
# 2879  felix dzerzhinsky kena serang jantung pidato j...                8
# 2880  perang silesia abad rivalitas konflik prusia a...                9
# 2881             versi dalam alkitab edisi nova vulgata                1
# 2882          marginalia rupa pakai dalam liturgi bakti                3
# ...                                                 ...              ...
# 3130  edisi terbatas tampil ilustrasi jk rowling ter...                7
# 3131  orang aktivis hak sipil muka kee pandang drama...               12
# 3132  ad universal ecclesiae konstitusi apostolik sy...               10
# 3133  pulau masuk dalam wilayah daulat negara republ...                2
# 3134  armada sia labuh wilayah eretria sepakat capai...               13
# 3135  orang pangeran muda keliling intelektual mente...                7
# 3136  anggota keluarga disney aktif libat dalam usah...                5
# 3137  kepung kota hasil tingkah laku jenderal sparta...                9
# 3138  whitlam milik suara mayoritas dalam dewan waki...                4
# 3139  intervensi dalam mogok pullman kereta api berj...                1
# 3140  tingkat karier monroe bayar operasi silikon im...               10
# 3141  ubah benda bentuk jamak reduplikasi ulang liba...                7
# 3142  panair do brasil dalam perang dunia ii dukung ...                3
# 3143  kabul alas pensiun gubernur jenderal campur da...                6
# 3144  robert noyce percaya microelektronik kembang d...                5
# 3145  sembilan persen orang afrikaamerika montgomery...                5
# 3146  laksana latih militer bagi warga kanakkanak pa...               12
# 3147  temu michael schiavo dalam kelas sosiologi buc...                3
# 3148  referensi warnawarna nama dalam bahasa inggris...                3
# 3149  alfabet koptik sejarah zaman dinasti ptolemaik...                8
# 3150  individu informasi non publik manfaat dalam da...                5
# 3151  kanuragan ilmu fungsi bela supranatural dalam ...                5
# 3152  sinergi unik baru kali indonesia usaha swasta ...               10
# 3153  muncul televisi hologram teknologi bas hologra...                6
# 3154  video klip grup tampil dalam acaraacara musik ...                4
# 3155  warung kopi timur tengah wilayah asia barat du...               12
# 3156  pegang pimpin utama dalam biliku keluarga bati...                3
# 3157  sd indonesia didik sekolah sdn lubuk baja temp...                8
# 3158  dalam aristophanes plutus ayat orang wanita tu...                0
# 3159  opera padu suara megah verdi komposer utama da...                7
#
#       targetpos_ori  targetpos_pos_tag  \
# 2853              8                  8
# 2854              5                  5
# 2855              6                  6
# 2856              6                  6
# 2857             10                 12
# 2858              5                  5
# 2859             14                 15
# 2860             16                 18
# 2861              5                  5
# 2862             18                 21
# 2863              5                  5
# 2864              1                  1
# 2865              1                  2
# 2866              7                  7
# 2867              4                  4
# 2868             13                 13
# 2869              7                  7
# 2870              2                  2
# 2871              5                  5
# 2872             28                 30
# 2873              1                  1
# 2874              7                  7
# 2875              1                  1
# 2876              7                  7
# 2877              7                  7
# 2878              9                  9
# 2879             11                 12
# 2880             20                 20
# 2881              3                  3
# 2882              5                  5
# ...             ...                ...
# 3130             12                 12
# 3131             18                 19
# 3132             17                 17
# 3133              6                  6
# 3134             28                 31
# 3135             17                 18
# 3136              8                  8
# 3137             13                 16
# 3138              5                  5
# 3139              1                  1
# 3140             16                 18
# 3141             18                 22
# 3142              7                  7
# 3143             13                 13
# 3144              8                  8
# 3145              9                  9
# 3146             19                 20
# 3147              7                  7
# 3148              9                  9
# 3149             13                 15
# 3150              8                  8
# 3151             11                 11
# 3152             22                 23
# 3153              9                 10
# 3154              7                  7
# 3155             19                 24
# 3156              4                  4
# 3157             16                 16
# 3158              2                  3
# 3159             11                 11
#
#                                           verbs  \
# 2853                                     adalah
# 2854                                hadap tolak
# 2855                                 liput bagi
# 2856                       ekor luka salah rasa
# 2857                            langsung adalah
# 2858                          pakai rupa dukung
# 2859                          hasil warna murni
# 2860                                     adalah
# 2861  jadi pro-traktat anti-traktat satu timbul
# 2862                         punya tingkat tahu
# 2863                                 catat meni
# 2864                   adalah usung usung usung
# 2865                               singgah temu
# 2866                            madam guna rupa
# 2867                                      cetak
# 2868                               dapat adalah
# 2869                                      mudah
# 2870                            variasi gantung
# 2871                                adalah rupa
# 2872                      padu diri tambah diri
# 2873                              rancang tutup
# 2874                              golong adalah
# 2875                                        ada
# 2876                              golong adalah
# 2877                              golong adalah
# 2878                                  muat rupa
# 2879                               tinggal kena
# 2880                       milik ada kuat mulai
# 2881                                       guna
# 2882                                      pakai
# ...                                         ...
# 3130                              terbit tampil
# 3131                       ekspresi lalu ungkap
# 3132                   atur masuk hubung adalah
# 3133                           baku masuk dapat
# 3134     hadap usaha tinggal adalah capai labuh
# 3135                            datang keliling
# 3136                              banding libat
# 3137                          senang buat hasil
# 3138                          imbau balik milik
# 3139                           buat jalan sebab
# 3140   diikutsertakan rhinoplasti bayar tingkat
# 3141                  libat kata jadi kata ubah
# 3142                           baik partisipasi
# 3143                                 ikut kabul
# 3144                 ujung guna kembang percaya
# 3145          boikot sebab kurang perintah ikut
# 3146      takut tempur jadi kanak-kanak laksana
# 3147                                       temu
# 3148          laku kenal rumus referensi adalah
# 3149                        salin lestari punya
# 3150              milik punya dapat lebih punya
# 3151             sebut sebut bela fungsi adalah
# 3152                        investasi beri jadi
# 3153                            guna bas muncul
# 3154                                tampil klip
# 3155                              dirorok sedia
# 3156                  bapak punya penuh sangkut
# 3157                               mulai tempuh
# 3158                                keluh habis
# 3159                                       diri
#
#                                                   nouns
# 2853                                   gera tokoh ulama
# 2854                          tahun militer bantu minta
# 2855  kategori duduk non-muslim duduk muslim non-pen...
# 2856                                             naruto
# 2857  rangkai skala latih invasi latih pantai kode nama
# 2858                             simbol warna klub klub
# 2859  terap oshibana bunga coklat warna tumbuh bunga...
# 2860                                       bagi singkat
# 2861  tubuh perang kelompok kelompok hendak friksi b...
# 2862  kembang kondisi percaya konstipasi khusus intr...
# 2863       hidup tulis kontemporer informasi istri saat
# 2864  pilih kandidat independen elam kandidat indepe...
# 2865                                   layar blambangan
# 2866                        alat bakar foamite komponen
# 2867                    huruf latin tahun terjemah teks
# 2868                        jumlah duduk mayoritas saat
# 2869                             akses unjung applikasi
# 2870                                 jumlah lokasi diet
# 2871                                   putra sakit ahli
# 2872                             kompleks lantai lantai
# 2873                                   wanita perempuan
# 2874                           kelas cachacrouensis aka
# 2875       akhir ionisasi atom disosiasi molekul energi
# 2876                                              kelas
# 2877                                              kelas
# 2878                      ukur seragam jenis buku karya
# 2879       temu dunia tanggal jam pidato jantung serang
# 2880  teritori luar kaisar negara konflik rivalitas ...
# 2881                                              versi
# 2882                                      liturgi bakti
# ...                                                 ...
# 3130  edisi standar edisi buat tangan ilustrasi bata...
# 3131         surat kabar bawah terbit drama hak aktivis
# 3132        ordo tarekat mana sumpah pria terima syarat
# 3133                         wilayah daulat pulau pulau
# 3134  kota kepung tahan kota rakyat sepakat wilayah ...
# 3135           tonjol masa menteri intelektual pangeran
# 3136                       usaha paman keluarga anggota
# 3137                pasu orang laku tingkah kota kepung
# 3138                  juru bicara putus mayoritas suara
# 3139                  kereta api kelompok serikat buruh
# 3140                 film rahang implan silikon operasi
# 3141  konteks ulang reduplikasi guna jamak bentuk benda
# 3142                   dukung pemerntah fasilitas tahun
# 3143                 perintah campur pensiun alas minta
# 3144  kompleksitas kondisi saat tanya bagaimana masy...
# 3145         dapat bus akhir adil desegregasi bus orang
# 3146        sejarah dunia pasu pasu warga militer latih
# 3147                                    kelas sosiologi
# 3148                         cara batas nama warna cara
# 3149       guna alfabet naskah tuju lafal zaman sejarah
# 3150  dagang saham sekuritas lebih investor untung i...
# 3151  bahasa negeri denga supranatural diri ilmu kan...
# 3152  pola kepelabuhanan bidang sempat usaha mana ha...
# 3153  dunia film film fiksi ilmiah hologram teknolog...
# 3154                                   acara musik grup
# 3155  variasi perisa ulen tembakau hookah shisha  du...
# 3156  biliku keluarga ama kepala keluarga hak wajib ...
# 3157       waktu tahun ajar sdn sekolah didik masa umum
# 3158                        ayat wanita uang kasih kini
# 3159                           abad komposer suara padu
#
# [307 rows x 10 columns]

# %% [markdown]
# # Training

# %%
dataset.to_csv('train_data.csv')

# %% [markdown]
# # Testing

# %%
dataset.to_csv('testing_data_clean.csv')

# %%
dataset
# Out:
#             kata sense                                            kalimat  \
# 0          cerah  4801             cuaca cerah adalah lazim panjang tahun
# 1          cerah  4801  gambar yang hasil oleh layarnya cukup cerah da...
# 2          cerah  4803  masa depan yang cerah bagi pemuda umur somenum...
# 3          cerah  4801  cor caroli alpha canum venaticorum nama lengka...
# 4          cerah  4801  sanders lebih suka cat air untuk lilo dengan m...
# 5          cerah  4801  ulleungdo milik iklim subtropis basah klasifik...
# 6          cerah  4801  ikan hias mungkin besar sulit tahan hidup di a...
# 7          cerah  4801  sebuah entremet tanda akhir saji suatu set men...
# 8          cerah  4801  alangkah lega hati ketika ia mulai lihat binat...
# 9         coklat  4703          sisi atas tubuh warna coklat tembaga emas
# 10        coklat  4703  lucy milik mata coklat dan rambut pirang panja...
# 11        coklat  4703  punggung dan badannya warna coklat kelabu deng...
# 12        coklat  4703  jenis koral yang seringkali temu adalah karang...
# 13        coklat  4703  kepala warna coklat merah dengan garis hitam d...
# 14        coklat  4703  pada remaja milik corak coklat bintik kuning k...
# 15         jalan  1902  rancang pei tempat kotak sepatu kaku di sebuah...
# 16         jalan  1903  selain jalan ceritakostum yang guna juga tidak...
# 17         jalan  1901  taraf hidup masyarakat tingkat dengan dukung b...
# 18         jalan  1901  dapat somenumber jalan tol besar yang hubung d...
# 19         jalan  1901  jumlah jalan dan tempat di kota ini beri nama ...
# 20         jalan  1901  tol serang panimbang rupa jalan tol yang hubun...
# 21         jalan  1901  tanah siang rupa jalan yang buat pada zaman ja...
# 22        sarung  1202  hela sarung tutup pinggang hingga kaki dan baj...
# 23        sarung  1202  lung juga kenal bagai sarung adalah pakai yang...
# 24        sarung  1201  kayu mahang damar tidak banyak manfaat palingp...
# 25        sarung  1201  anton gabrielle alias the wonderboy robertino ...
# 26        sarung  1202  sarung adalah pakai dari komunitas laut di sem...
# 27        sarung  1201  sedang dalam video game pokemon emerald tampil...
# 28        sarung  1202  kainkain sebut kena bagai sarung setinggi dada...
# 29        sarung  1202  sarung muna rupa kain tenun khas buat suku mun...
# ...          ...   ...                                                ...
# 8377    menerima  3101  pada juli somenumber pluna menerima pesawat li...
# 8378    menerima  3101  atrium fungsi bagai ruang resepsi tempat pater...
# 8379    menerima  3101  pada tahun somenumber ia menerima beasiswa mil...
# 8380  mengandung  2301  tidak ada inti stabil di alam yang mengandung ...
# 8381  mengandung  2301  target utama misi ini adalah europa yang duga ...
# 8382  mengandung  2301  pada somenumber januari somenumber sanger umum...
# 8383  mengandung  2301  band ini kenal dengan genre metalcore pada deb...
# 8384  mengandung  2301  dapat lebih dari somenumber buku yang judul me...
# 8385  mengandung  2301  satelit jenis ini juga dapat monitor ubah ikli...
# 8386  mengandung  2301  enclosed alphanumeric supplement adalah blok u...
# 8387  mengandung  2301  khmer adalah blok unicode yang mengandung kara...
# 8388  mengandung  2301  softlens lensa kontak adalah sebuah alat yang ...
# 8389  mengandung  2301  daun kubis juga mengandung kelompok glukosinol...
# 8390  mengandung  2301  banyak seni beladiri mengandung latih gumul wa...
# 8391  mengandung  2301  pusat germinal pertama kali didefinisikan oleh...
# 8392  mengandung  2301     buah ini mengandung banyak vitamin c dan tanin
# 8393  mengandung  2301  akibat koh biasa mengandung bagai jumlah air s...
# 8394  mengandung  2301  senyawa yang mengandung lebih dari somenumber ...
# 8395  mengandung  2301  di samping mengandung bisa air liur komodo jug...
# 8396  mengandung  2301  sekitar somenumber pasien yang tangan dengan d...
# 8397  mengandung  2301  tapi lokasi taj mengandung beberapa kubur tida...
# 8398  mengandung  2301  dapat beberapa kombinasi vaksin antara vaksin ...
# 8399  mengandung  2301  pada kasus tentu implan mengandung perangkat e...
# 8400  mengandung  2301  di samping dua singel sebut isi lagu dalam alb...
# 8401  mengandung  2301  maka seluruh alam semesta mengandung diri alla...
# 8402  mengandung  2301  molekulmolekul yang mengandung 4n elektron pi ...
# 8403  mengandung  2301  kira salar de uyuni mengandung somenumber mili...
# 8404  mengandung  2301  injil yang ada saat ini mengandung firman alla...
# 8405  mengandung  2301  selain itu sebagian episode mengandung tidak s...
# 8406  mengandung  2301  para teliti telah kembang galur semanggi tentu...
#
#                                                pos_tags  \
# 0                                   NN NN VB NN NN NN Z
# 1     NNP SC VB IN NN RB JJ CC VB NN SC JJ VB NN SC ...
# 2               NN NN SC VB IN NN NN CD IN NNP NNP CD Z
# 3     NNP NNP Z NNP NNP NNP Z Z Z NN RB VB NNP NNP N...
# 4       NN RB VB NN NN SC NNP IN NN VB NN NN NN NN NN Z
# 5     NNP VB NN JJ VB Z NN NN NNP NNP Z Z SC IN NN N...
# 6     VB NN NN JJ JJ VB NN IN NN JJ NN NN SC NN CC R...
# 7     NND NN VB NN NN CD NN NN CC MD VB WH RB VB IN ...
# 8     NN NN NN SC PRP VB VB NN NN NN IN NN NN NN Z V...
# 9                                NN IN NN NN NN NN NN Z
# 10    NNP VB NN NN CC VB NN NN VB SC RB VB IN NN IN ...
# 11             NN CC RB VB NN NN IN CD NN JJ NN JJ RB Z
# 12    NN JJ SC RB VB VB NN NN Z NNP VB Z SC VB NN NN...
# 13                   NN NN NN NN IN NN JJ IN NN IN NN Z
# 14                            IN NN VB NN NN NN NN NN Z
# 15             NN NNP VB NN CD NN IN NND NN IN NN NN IN
# 16                   IN NN NN Z NN SC VB RB NEG JJ RB Z
# 17    NN NN NN VB SC VB NN NN NN Z NN NN NN SC VB IN...
# 18    VB CD NN NN JJ SC VB NNP NNP NNP NNP NNP IN NN...
# 19    CD NN CC NN IN NN PR VB NN NN Z NN Z CC VB Z I...
# 20    NNP NNP NNP NNP VB NN NN SC VB NNP CC NNP NNP ...
# 21               NNP NNP VB NN SC VB IN NN NN NNP NNP Z
# 22    NN NN VB NN IN NN CC NN JJ VB IN NN NN Z VB NN...
# 23               VB Z RB VB IN NN Z VB NN SC VB IN NN Z
# 24     NN NN NN NEG CD VB Z FW IN NN NN VB Z CC NN NN Z
# 25    NNP NNP NNP NNP NNP Z NNP Z NN NN NN Z VB VB N...
# 26        NNP VB NN IN NN NN IN NNP NNP JJ NNP CC NNP Z
# 27    CC IN NN NN NNP NNP Z RB RB JJ SC IN NN JJ NNP...
# 28             IN PR VB IN NN JJ VB IN NN VB VB NN NN Z
# 29             NN SC VB IN NN VB NN NNP NNP Z NNP NNP Z
# ...                                                 ...
# 8377           IN NNP CD NNP VB NN RB Z IN NN CD NN Z Z
# 8378  NN NN IN NN NN NN NN JJ Z Z NN NN NN Z NN SC R...
# 8379  IN NN CD Z PRP VB NN NN JJ SC VB IN NN IN NNP ...
# 8380  NEG VB NN JJ IN NN SC VB CD NND Z SC VB FW FW ...
# 8381  NN JJ NN PR VB NNP Z SC VB VB NN IN NN NN SC M...
# 8382  IN CD NNP CD Z NNP VB SC NN PR MD Z IN NN Z RB...
# 8383  NNP PR VB IN FW FW IN VB PRP NNP NNP NNP NNP Z...
# 8384        VB RB IN CD NN SC RB VB VB NN NN Z NN Z Z Z
# 8385  NN NN PR RB MD VB NN NN Z NN JJ Z CC NN NN NN ...
# 8386  NNP NNP NNP VB NN NN SC VB NN NNP NNP SC VB NN...
# 8387       NNP VB NN NN SC VB NN SC NN NNP NNP CC NNP Z
# 8388  NNP Z NN NN Z VB NND NN SC VB SC VB NN IN NN N...
# 8389                NNP VB RB VB NN NN SC VB NN RB JJ Z
# 8390                     CD NN NN VB NN NN Z SC RB VB Z
# 8391  NN JJ OD NND VB IN NNP NNP IN NN CD IN NN NN S...
# 8392                      NND PR VB CD NN NNP Z CC NN Z
# 8393     RB Z NNP RB VB CD NN NN Z CC NN Z VB IN NN Z Z
# 8394                  NNP SC VB RB IN CD NND NN RB VB Z
# 8395  IN NN VB MD Z NN NN NN RB VB PRP NN VB IN NN Z...
# 8396  IN CD SYM NN SC VB IN NNP VB NN CC NN RB RB JJ...
# 8397             CC NN NNP VB CD NN RB IN CD NN CC RB Z
# 8398  VB CD NN NN IN NN JJ IN NN JJ Z IN NNP CC NNP ...
# 8399                    IN NN NN NN VB NN NN IN NN NN Z
# 8400  IN NN CD NN PR Z NN NN IN NN PR VB RB NN CC VB...
# 8401  SC CD NN JJ VB NN NNP Z SC NNP VB RB VB SC JJ ...
# 8402                         NN SC VB CD NND NN VB NN Z
# 8403  VB Z NNP NNP NNP VB CD CD NND NN Z CC RB IN IN...
# 8404  NNP SC VB NN PR VB NN NNP CC NN NNP Z SC RB VB...
# 8405            IN PR Z CD NN VB RB CD NN IN NN NN NN Z
# 8406  DT NN MD VB NN NN JJ SC VB CD NN CC NN NN SC V...
#
#                                                   clean  targetpos_clean  \
# 0                                     cuaca cerah lazim                1
# 1     gambar hasil layarnya cerah milik speaker hasi...                3
# 2                   cerah bagi pemuda umur prancis abad                0
# 3     cor caroli alpha canum venaticorum nama lengka...               12
# 4     sanders suka cat air lilo maksud tampil warna ...                8
# 5     ulleungdo milik iklim subtropis basah klasifik...               14
# 6     ikan hias besar sulit tahan hidup alam liar ak...               10
# 7     entremet tanda saji set menu upa frumenty sede...               11
# 8     alangkah lega hati lihat binatangbinatang tern...               13
# 9             sisi atas tubuh warna coklat tembaga emas                4
# 10    lucy milik mata coklat rambut pirang bahu diik...                3
# 11    punggung badannya warna coklat kelabu garis hi...                3
# 12    jenis koral seringkali temu karang daging pori...               10
# 13    kepala warna coklat merah garis hitam mata ten...                2
# 14    remaja milik corak coklat bintik kuning kecokl...                3
# 15       rancang pei kotak sepatu kaku sudut kisi jalan                7
# 16                      jalan ceritakostum sesuai zaman                0
# 17    taraf hidup masyarakat tingkat dukung jalan de...                5
# 18    jalan tol besar hubung distrik bisnis sentral ...                0
# 19    jalan kota nama ilmuwan matematikawan temu die...                0
# 20    tol serang panimbang rupa jalan tol hubung ser...                4
# 21    tanah siang rupa jalan zaman jajah hindia belanda                3
# 22    hela sarung tutup pinggang kaki baju tipis lon...                1
# 23                lung kenal sarung pakai kena pinggang                2
# 24    kayu mahang damar manfaat palingpaling sarung ...                5
# 25    anton gabrielle alias the wonderboy robertino ...               10
# 26    sarung pakai komunitas laut semenanjung malaya...                0
# 27    dalam video game pokemon emerald tampil versi ...               20
# 28       kainkain kena sarung dada bahu tutup taba huku                2
# 29    sarung muna rupa kain tenun khas suku muna sul...                0
# ...                                                 ...              ...
# 8377            juli pluna menerima pesawat total pesan                2
# 8378  atrium fungsi ruang resepsi paterfamilias kepa...               16
# 8379          menerima beasiswa militer ajar tank mesir                0
# 8380  inti stabil alam mengandung nukleon bottleneck...                3
# 8381  target utama misi europa duga milik samudra mu...                8
# 8382  januari sanger proyek eksperimen mengandung ar...                4
# 8383  band kenal genre metalcore debut sounding the ...                9
# 8384             buku judul mengandung pemimipin leader                2
# 8385  satelit jenis monitor ubah iklim teliti ekolog...               10
# 8386  enclosed alphanumeric supplement blok unicode ...                5
# 8387  khmer blok unicode mengandung karakter tulis b...                3
# 8388  softlens lensa kontak alat bantu lihat ganti k...               13
# 8389  daun kubis mengandung kelompok glukosinolat pahit                2
# 8390  seni beladiri mengandung latih gumul tekan var...                2
# 8391  pusat germinal kali walther flemming mikroanat...               10
# 8392                    buah mengandung vitamin c tanin                1
# 8393           akibat koh mengandung air karbonat lihat                2
# 8394                   senyawa mengandung jenis halogen                1
# 8395  samping mengandung bisa air liur komodo milik ...                1
# 8396  pasien tangan dapson derita hemolisis efek sam...               14
# 8397  lokasi taj mengandung kubur paviliun timur sel...                2
# 8398  kombinasi vaksin vaksin tetanus vaksin dtap td...                7
# 8399     implan mengandung perangkat elektronik jantung                1
# 8400  samping singel isi lagu dalam album kenal kela...                8
# 8401  alam semesta mengandung allah allah satusatuny...                2
# 8402  molekulmolekul mengandung 4n elektron pi antia...                1
# 8403  salar de uyuni mengandung miliar ton garam ton...                3
# 8404  injil mengandung firman allah riwayat isa tuli...                1
# 8405              episode mengandung dalam bahasa bunga                1
# 8406  teliti kembang galur semanggi mengandung kumar...                4
#
#       targetpos_ori  targetpos_pos_tag
# 0                 1                  1
# 1                 6                  6
# 2                 3                  3
# 3                16                 21
# 4                11                 11
# 5                18                 21
# 6                13                 13
# 7                22                 24
# 8                19                 20
# 9                 4                  4
# 10                3                  3
# 11                4                  4
# 12               14                 17
# 13                2                  2
# 14                4                  4
# 15               11                 11
# 16                1                  1
# 17                7                  7
# 18                2                  2
# 19                1                  1
# 20                4                  5
# 21                3                  3
# 22                1                  1
# 23                4                  5
# 24                8                  9
# 25               11                 14
# 26                0                  0
# 27               32                 36
# 28                4                  4
# 29                0                  0
# ...             ...                ...
# 8377              4                  4
# 8378             24                 29
# 8379              4                  5
# 8380              7                  7
# 8381             15                 16
# 8382             13                 16
# 8383             14                 15
# 8384              7                  7
# 8385             15                 17
# 8386              7                  7
# 8387              5                  5
# 8388             25                 28
# 8389              3                  3
# 8390              3                  3
# 8391             21                 21
# 8392              2                  2
# 8393              3                  4
# 8394              2                  2
# 8395              2                  2
# 8396             28                 30
# 8397              3                  3
# 8398             15                 16
# 8399              4                  4
# 8400             14                 15
# 8401              4                  4
# 8402              2                  2
# 8403              4                  5
# 8404              5                  5
# 8405              4                  5
# 8406              8                  8
#
# [8407 rows x 8 columns]
